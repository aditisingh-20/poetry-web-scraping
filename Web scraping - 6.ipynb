# %% [markdown]
# # Text Generation

# %% [markdown]
# ## Select Text to Imitate

# %%
import pandas as pd

data = pd.read_pickle('data_clean.pkl')
data
# Out:
#                                                   transcript
# allen      i saw the best minds of my generation destroye...
# axentioi   for what you might be last withwe might not un...
# christina  hurt no living thing ladybird nor butterfly no...
# george     when we two parted  in silence and tears half ...
# iff        loose leaves fall   from winter gray     calen...
# judith     the eyeless labourer in the nightthe selfless ...
# max        let me do my work each day and if the darkened...
# nuno       im walking the dog its raining he sniffs and p...
# paul       we wear the mask that grins and liesit hides o...
# sammeh     who the fuck did you call when you were coked ...

# %%
allen_text = data.transcript.loc['allen']
allen_text[:200]
# Out:
# 'i saw the best minds of my generation destroyed by     madness starving hysterical nakeddragging themselves through the negro streets at dawn     looking for an angry fix angelheaded hipsters burning '

# %% [markdown]
# ## Build a Markov Chain Function

# %%
from collections import defaultdict

def markov_chain(text):
    '''The input is a string of text and the output will be a dictionary with each word as
       a key and each value as the list of words that come after the key in the text.'''
    
    words = text.split(' ')

    m_dict = defaultdict(list)

    for current_word, next_word in zip(words[0:-1], words[1:]):
        m_dict[current_word].append(next_word)

    m_dict = dict(m_dict)
    return m_dict

# %%
allen_dict = markov_chain(allen_text)
allen_dict
# Out:
# {'i': ['saw', 'had', 'am', 'sit', 'dream', 'am', 'abandon', 'am'],
#  'saw': ['the', 'mohammedan', 'it'],
#  'the': ['best',
#   'negro',
#   'ancient',
#   'starry',
#   'machin',
#   'supernatural',
#   'tops',
#   'el',
#   'scholars',
#   'academies',
#   'windows',
#   '',
#   'terror',
#   'wall',
#   'mind',
#   'mo',
#   'rooftops',
#   'roaring',
#   'endless',
#   'noise',
#   'drear',
#   'stale',
#   'crack',
#   'hydrogen',
#   'brook',
#   'stoops',
#   'moon',
#   '',
#   'pavement',
#   '',
#   'cross',
#   'cosmos',
#   'streets',
#   'chinaman',
#   'impulse',
#   '',
#   'volcanoes',
#   'shadow',
#   'lava',
#   'west',
#   '',
#   'narcotic',
#   'sirens',
#   'staten',
#   'machinery',
#   'neck',
#   'subway',
#   'roof',
#   'ass',
#   'sailors',
#   'morning',
#   'evenings',
#   'grass',
#   'blond',
#   'three',
#   'one',
#   'heterosexual',
#   'one',
#   'womb',
#   'one',
#   'intellectual',
#   'craftsmans',
#   'bed',
#   'floor',
#   'hall',
#   'wall',
#   'last',
#   'snatches',
#   'sunset',
#   'morning',
#   'snatch',
#   'sun',
#   'lake',
#   'memory',
#   'snowbank',
#   '',
#   'apartment',
#   'hudson',
#   'wartime',
#   'moon',
#   'lamb',
#   'imagination',
#   'crab',
#   'muddy',
#   'rivers',
#   'romance',
#   'streets',
#   'darkness',
#   '',
#   'sixth',
#   'tubercular',
#   'yellow',
#   'pure',
#   'roof',
#   'next',
#   'tankedup',
#   'iron',
#   'nitroglycerine',
#   '',
#   'mustard',
#   '',
#   'brooklyn',
#   'ghostly',
#   'subway',
#   'filthy',
#   'street',
#   'whiskey',
#   'bloody',
#   'blast',
#   'highways',
#   'past',
#   '',
#   'soul',
#   '',
#   'black',
#   '',
#   'radio',
#   '',
#   'madhouse',
#   'concrete',
#   'visible',
#   'wards',
#   'madtowns',
#   '',
#   'echoes',
#   'soul',
#   'midnight',
#   '',
#   'last',
#   'tenement',
#   'last',
#   'last',
#   'wall',
#   'last',
#   'last',
#   'closet',
#   'total',
#   'icy',
#   'alchemy',
#   'use',
#   'ellipse',
#   'catalog',
#   'meter',
#   'vibrat',
#   '',
#   'soul',
#   'elemental',
#   'noun',
#   'syntax',
#   'soul',
#   'rhythm',
#   'madman',
#   'ghostly',
#   'goldhorn',
#   'band',
#   '',
#   'cities',
#   'last',
#   'absolute',
#   'poem',
#   '',
#   'parks',
#   '',
#   'heavy',
#   'incomprehensible',
#   '',
#   'vast',
#   'stun',
#   'long',
#   'fog',
#   'cities',
#   'specter',
#   'mind',
#   'sky',
#   'city',
#   'american',
#   'whole',
#   'river',
#   'flood',
#   'rocks',
#   'river',
#   '',
#   'holy',
#   'roof',
#   'river',
#   '',
#   'shade',
#   'same',
#   'radio',
#   'faculties',
#   'skull',
#   'worms',
#   'senses',
#   'tea',
#   'breasts',
#   '',
#   'bodies',
#   '',
#   'bronx',
#   'game',
#   'actual',
#   '',
#   'catatonic',
#   'soul',
#   'void',
#   'hebrew',
#   '',
#   'heavens',
#   '',
#   'final',
#   'internationale',
#   'united',
#   'united',
#   'coma',
#   '',
#   '',
#   'eternal',
#   'highway',
#   'door',
#   'western'],
#  'best': ['minds'],
#  'minds': ['of', 'in', 'new'],
#  'of': ['my',
#   'night',
#   '',
#   'cities',
#   'war',
#   'the',
#   'marijuana',
#   'shuddering',
#   '',
#   'time',
#   'halls',
#   'teahead',
#   'brook',
#   'mind',
#   'wheels',
#   'brain',
#   'brilliance',
#   'zoo',
#   'bickfords',
#   'doom',
#   'platonic',
#   'the',
#   'hospitals',
#   'ambiguous',
#   'atlantic',
#   'china',
#   'the',
#   'idaho',
#   'okla',
#   'winter',
#   'mexico',
#   'dungarees',
#   'poetry',
#   'capitalism',
#   'los',
#   'other',
#   'atlantic',
#   'public',
#   'fate',
#   'the',
#   'the',
#   'the',
#   '',
#   'cigarettes',
#   'ultimate',
#   'consciousness',
#   'a',
#   'the',
#   'these',
#   'denverjoy',
#   'his',
#   'girls',
#   'johns',
#   'basements',
#   'third',
#   'blood',
#   'steamheat',
#   'the',
#   'the',
#   'the',
#   'the',
#   '',
#   'the',
#   'onions',
#   'harlem',
#   'theology',
#   'gibberish',
#   'the',
#   'time',
#   'leaden',
#   'the',
#   'fashion',
#   'the',
#   'advertising',
#   'sinis',
#   'absolute',
#   'chinatown',
#   'their',
#   '',
#   'nostalgic',
#   'colossal',
#   'the',
#   'reality',
#   'hyp',
#   'the',
#   'suicide',
#   'insulin',
#   '',
#   'the',
#   'the',
#   'the',
#   'the',
#   'love',
#   'life',
#   'the',
#   '',
#   '',
#   '',
#   'the',
#   'the',
#   'the',
#   'the',
#   'consciousness',
#   'pater',
#   'poor',
#   'thought',
#   'jazz',
#   'the',
#   'americas',
#   'the',
#   'life',
#   'their',
#   'cement',
#   'moloch',
#   'men',
#   '',
#   'war',
#   'genius',
#   'sexless',
#   'my',
#   'the',
#   'sensitive',
#   'timereal',
#   'my',
#   'the',
#   'the',
#   'the',
#   'the',
#   'utica',
#   'your',
#   'the',
#   'the',
#   'the',
#   'insanity',
#   'long',
#   '',
#   'the',
#   'mercy',
#   'my'],
#  'my': ['generation', 'soul', 'natural', 'mother', 'dreams', 'cottage'],
#  'generation': ['destroyed', 'down'],
#  'destroyed': ['by'],
#  'by': ['', 'saintly', 'those', 'orange', 'the', 'our', 'owner'],
#  '': ['',
#   '',
#   '',
#   'madness',
#   '',
#   '',
#   '',
#   'looking',
#   '',
#   '',
#   '',
#   'connection',
#   '',
#   '',
#   'ery',
#   '',
#   '',
#   '',
#   'up',
#   '',
#   '',
#   '',
#   'coldwater',
#   '',
#   '',
#   '',
#   'contemplating',
#   '',
#   '',
#   '',
#   'saw',
#   '',
#   '',
#   'ment',
#   '',
#   '',
#   '',
#   'hallucinating',
#   '',
#   '',
#   '',
#   'among',
#   '',
#   '',
#   '',
#   '',
#   'publishing',
#   '',
#   '',
#   '',
#   'skull',
#   '',
#   '',
#   'ing',
#   '',
#   '',
#   '',
#   'to',
#   '',
#   '',
#   '',
#   'laredo',
#   '',
#   '',
#   '',
#   'paradise',
#   '',
#   '',
#   '',
#   'torsos',
#   '',
#   '',
#   'cohol',
#   '',
#   '',
#   '',
#   'lightning',
#   '',
#   '',
#   '',
#   'canada',
#   'paterson',
#   '',
#   '',
#   'tionless',
#   '',
#   '',
#   '',
#   'dawns',
#   '',
#   '',
#   '',
#   'storefront',
#   '',
#   '',
#   '',
#   'blinking',
#   '',
#   '',
#   '',
#   'vibrations',
#   '',
#   '',
#   'lyn',
#   '',
#   '',
#   '',
#   'ride',
#   '',
#   '',
#   '',
#   'until',
#   '',
#   '',
#   '',
#   'them',
#   '',
#   '',
#   '',
#   'battered',
#   '',
#   '',
#   '',
#   'in',
#   '',
#   '',
#   '',
#   'floated',
#   '',
#   '',
#   'noon',
#   '',
#   '',
#   '',
#   'of',
#   '',
#   '',
#   '',
#   'pad',
#   '',
#   '',
#   'lyn',
#   'lost',
#   '',
#   '',
#   '',
#   'down',
#   '',
#   '',
#   '',
#   'off',
#   '',
#   '',
#   '',
#   'and',
#   '',
#   '',
#   '',
#   'and',
#   '',
#   '',
#   '',
#   'and',
#   '',
#   '',
#   '',
#   'synagogue',
#   '',
#   '',
#   '',
#   'trail',
#   '',
#   '',
#   '',
#   'city',
#   '',
#   '',
#   'ings',
#   '',
#   '',
#   'drawal',
#   '',
#   '',
#   '',
#   'railroad',
#   '',
#   '',
#   '',
#   'leaving',
#   '',
#   '',
#   '',
#   'through',
#   '',
#   '',
#   'father',
#   '',
#   '',
#   'athy',
#   '',
#   '',
#   'stinctively',
#   '',
#   '',
#   'ionary',
#   '',
#   '',
#   '',
#   'angels',
#   '',
#   '',
#   '',
#   'gleamed',
#   '',
#   '',
#   'homa',
#   '',
#   '',
#   'light',
#   '',
#   '',
#   '',
#   'seeking',
#   '',
#   '',
#   '',
#   'brilliant',
#   '',
#   '',
#   '',
#   'and',
#   '',
#   '',
#   '',
#   'to',
#   '',
#   '',
#   '',
#   'behind',
#   '',
#   '',
#   '',
#   'and',
#   '',
#   '',
#   'place',
#   '',
#   '',
#   '',
#   'fbi',
#   '',
#   '',
#   '',
#   'eyes',
#   '',
#   '',
#   'prehensible',
#   '',
#   '',
#   '',
#   'the',
#   '',
#   '',
#   '',
#   'square',
#   '',
#   '',
#   '',
#   'of',
#   '',
#   '',
#   '',
#   'down',
#   '',
#   '',
#   '',
#   'wailed',
#   '',
#   '',
#   '',
#   'and',
#   '',
#   '',
#   '',
#   'skeletons',
#   '',
#   '',
#   '',
#   'in',
#   '',
#   '',
#   '',
#   'own',
#   '',
#   '',
#   '',
#   'dragged',
#   '',
#   '',
#   'scripts',
#   '',
#   '',
#   '',
#   'motorcyclists',
#   '',
#   '',
#   '',
#   'the',
#   '',
#   '',
#   '',
#   'love',
#   '',
#   '',
#   'gardens',
#   '',
#   '',
#   '',
#   'cemeteries',
#   '',
#   '',
#   '',
#   'whomever',
#   '',
#   '',
#   '',
#   'with',
#   '',
#   '',
#   '',
#   'when',
#   'naked',
#   '',
#   '',
#   '',
#   'them',
#   '',
#   '',
#   '',
#   'the',
#   '',
#   '',
#   '',
#   'the',
#   '',
#   '',
#   '',
#   'and',
#   '',
#   '',
#   '',
#   'sit',
#   '',
#   '',
#   '',
#   'threads',
#   '',
#   '',
#   '',
#   'beer',
#   '',
#   '',
#   'dle',
#   '',
#   '',
#   '',
#   'the',
#   '',
#   '',
#   '',
#   'on',
#   '',
#   '',
#   '',
#   'come',
#   '',
#   '',
#   '',
#   'in',
#   '',
#   '',
#   '',
#   'but',
#   '',
#   '',
#   'rise',
#   '',
#   '',
#   '',
#   'in',
#   '',
#   '',
#   '',
#   'stolen',
#   '',
#   '',
#   '',
#   'poems',
#   '',
#   '',
#   '',
#   'to',
#   '',
#   '',
#   '',
#   'in',
#   'diner',
#   '',
#   '',
#   '',
#   'rickety',
#   '',
#   '',
#   '',
#   'gaunt',
#   '',
#   '',
#   'ticoat',
#   'especially',
#   '',
#   '',
#   '',
#   'solipsisms',
#   'hometown',
#   '',
#   '',
#   '',
#   'dreams',
#   '',
#   '',
#   '',
#   'picked',
#   '',
#   '',
#   'over',
#   '',
#   '',
#   '',
#   'avenue',
#   'stumbled',
#   '',
#   '',
#   'ment',
#   '',
#   '',
#   '',
#   'the',
#   '',
#   '',
#   '',
#   'east',
#   '',
#   '',
#   '',
#   'and',
#   '',
#   '',
#   '',
#   'cliffbanks',
#   '',
#   '',
#   '',
#   'blue',
#   'their',
#   '',
#   '',
#   '',
#   'be',
#   '',
#   '',
#   '',
#   'the',
#   '',
#   '',
#   '',
#   'bowery',
#   '',
#   '',
#   '',
#   'pushcarts',
#   '',
#   '',
#   '',
#   'bridge',
#   '',
#   '',
#   '',
#   'their',
#   '',
#   '',
#   '',
#   'with',
#   '',
#   '',
#   '',
#   'by',
#   '',
#   '',
#   '',
#   'incantations',
#   '',
#   '',
#   '',
#   'stanzas',
#   '',
#   '',
#   '',
#   '',
#   'tortillas',
#   '',
#   '',
#   '',
#   'kingdom',
#   '',
#   '',
#   '',
#   'an',
#   '',
#   '',
#   '',
#   'for',
#   'alarm',
#   '',
#   '',
#   '',
#   'fell',
#   '',
#   '',
#   'fully',
#   '',
#   '',
#   '',
#   'stores',
#   '',
#   '',
#   '',
#   'old',
#   '',
#   '',
#   '',
#   'on',
#   '',
#   '',
#   '',
#   '',
#   'the',
#   '',
#   '',
#   '',
#   'of',
#   'the',
#   '',
#   '',
#   '',
#   'fairies',
#   'the',
#   '',
#   '',
#   'ter',
#   '',
#   '',
#   '',
#   'drunken',
#   '',
#   '',
#   'pened',
#   '',
#   '',
#   '',
#   'into',
#   '',
#   '',
#   'ways',
#   'firetrucks',
#   '',
#   '',
#   '',
#   'the',
#   '',
#   '',
#   'saic',
#   '',
#   '',
#   '',
#   'danced',
#   '',
#   '',
#   '',
#   'phonograph',
#   '',
#   '',
#   '',
#   '',
#   'german',
#   '',
#   '',
#   '',
#   'threw',
#   '',
#   '',
#   '',
#   'in',
#   '',
#   '',
#   'whistles',
#   '',
#   '',
#   '',
#   'to',
#   '',
#   '',
#   '',
#   'watch',
#   '',
#   '',
#   '',
#   'if',
#   '',
#   '',
#   '',
#   'a',
#   '',
#   '',
#   '',
#   'came',
#   'waited',
#   '',
#   '',
#   '',
#   'watched',
#   'brooded',
#   'loned',
#   '',
#   '',
#   '',
#   'denver',
#   '',
#   '',
#   '',
#   'time',
#   'now',
#   '',
#   '',
#   '',
#   'for',
#   '',
#   '',
#   '',
#   'until',
#   '',
#   '',
#   '',
#   'impossible',
#   '',
#   '',
#   '',
#   'charm',
#   '',
#   '',
#   '',
#   'blues',
#   '',
#   '',
#   '',
#   'mount',
#   '',
#   '',
#   '',
#   'or',
#   '',
#   '',
#   '',
#   'harvard',
#   '',
#   '',
#   '',
#   'daisychain',
#   '',
#   '',
#   'notism',
#   'were',
#   'their',
#   '',
#   '',
#   '',
#   'hands',
#   'a',
#   '',
#   '',
#   '',
#   'and',
#   '',
#   '',
#   '',
#   'granite',
#   '',
#   '',
#   '',
#   'and',
#   '',
#   '',
#   'stantaneous',
#   '',
#   '',
#   '',
#   'metrazol',
#   '',
#   '',
#   'therapy',
#   '',
#   '',
#   '',
#   '',
#   'amnesia',
#   '',
#   '',
#   '',
#   'pingpong',
#   '',
#   '',
#   '',
#   'blood',
#   '',
#   '',
#   'man',
#   '',
#   '',
#   '',
#   'east',
#   '',
#   '',
#   '',
#   'halls',
#   '',
#   '',
#   'ing',
#   '',
#   '',
#   '',
#   'dolmenrealms',
#   '',
#   '',
#   'mare',
#   '',
#   '',
#   '',
#   'moon',
#   'and',
#   '',
#   '',
#   '',
#   'flung',
#   '',
#   '',
#   '',
#   'door',
#   'am',
#   '',
#   '',
#   '',
#   'slammed',
#   '',
#   '',
#   'nished',
#   '',
#   '',
#   '',
#   'mental',
#   '',
#   '',
#   '',
#   'on',
#   '',
#   '',
#   '',
#   'imaginary',
#   '',
#   '',
#   '',
#   'hallucinationah',
#   '',
#   '',
#   '',
#   'now',
#   '',
#   '',
#   '',
#   'timeand',
#   '',
#   '',
#   '',
#   'with',
#   '',
#   '',
#   '',
#   'of',
#   'the',
#   '',
#   '',
#   'ing',
#   'space',
#   '',
#   '',
#   '',
#   'through',
#   '',
#   '',
#   '',
#   'archangel',
#   'visual',
#   '',
#   '',
#   '',
#   'and',
#   '',
#   '',
#   '',
#   'and',
#   '',
#   '',
#   '',
#   'with',
#   '',
#   '',
#   '',
#   'deus',
#   '',
#   '',
#   '',
#   'prose',
#   '',
#   '',
#   'ligent',
#   '',
#   '',
#   'fessing',
#   '',
#   '',
#   '',
#   'of',
#   '',
#   '',
#   '',
#   'yet',
#   '',
#   '',
#   '',
#   'in',
#   '',
#   '',
#   '',
#   'the',
#   '',
#   '',
#   '',
#   'suffering',
#   '',
#   '',
#   '',
#   'an',
#   '',
#   '',
#   '',
#   'cry',
#   '',
#   '',
#   '',
#   'out',
#   '',
#   '',
#   '',
#   'years',
#   '',
#   '',
#   '',
#   'their',
#   '',
#   '',
#   'nation',
#   '',
#   '',
#   'tainable',
#   '',
#   '',
#   '',
#   'stairways',
#   '',
#   '',
#   '',
#   'weeping',
#   '',
#   '',
#   '',
#   'loveless',
#   '',
#   '',
#   '',
#   'judger',
#   '',
#   '',
#   '',
#   'crossbone',
#   '',
#   '',
#   '',
#   'sorrows',
#   '',
#   '',
#   '',
#   'moloch',
#   '',
#   '',
#   'ned',
#   '',
#   '',
#   '',
#   'blood',
#   '',
#   '',
#   '',
#   'are',
#   '',
#   '',
#   'bal',
#   '',
#   '',
#   '',
#   'tomb',
#   '',
#   '',
#   '',
#   'moloch',
#   '',
#   '',
#   '',
#   'streets',
#   '',
#   '',
#   'tories',
#   '',
#   '',
#   '',
#   'smokestacks',
#   '',
#   '',
#   '',
#   'whose',
#   '',
#   '',
#   '',
#   'whose',
#   '',
#   '',
#   '',
#   'whose',
#   '',
#   '',
#   '',
#   'moloch',
#   '',
#   '',
#   '',
#   'angels',
#   '',
#   '',
#   '',
#   'moloch',
#   '',
#   '',
#   '',
#   'i',
#   '',
#   '',
#   '',
#   'who',
#   '',
#   '',
#   '',
#   'moloch',
#   '',
#   '',
#   '',
#   'light',
#   '',
#   '',
#   '',
#   'skeleton',
#   '',
#   '',
#   '',
#   'industries',
#   '',
#   '',
#   '',
#   'houses',
#   '',
#   '',
#   'ments',
#   '',
#   '',
#   ...],
#  'madness': ['starving'],
#  'starving': ['hysterical'],
#  'hysterical': ['nakeddragging'],
#  'nakeddragging': ['themselves'],
#  'themselves': ['through', 'to', 'be', 'up', 'under', 'on'],
#  'through': ['the',
#   'universities',
#   'the',
#   '',
#   'the',
#   'snow',
#   'the',
#   'houston',
#   'colorado',
#   'their',
#   'the',
#   'images'],
#  'negro': ['streets'],
#  'streets': ['at', 'of', 'of', 'with', 'obsessed', 'like'],
#  'at': ['dawn',
#   'midnight',
#   'their',
#   'the',
#   'the',
#   'ccny',
#   '',
#   'the',
#   'this',
#   'no'],
#  'dawn': [''],
#  'looking': ['for', 'for'],
#  'for': ['an',
#   'the',
#   'crazy',
#   'new',
#   'the',
#   'seven',
#   'the',
#   'committing',
#   'a',
#   '',
#   'eternity',
#   'the',
#   'her',
#   'each',
#   'a',
#   '',
#   'a',
#   'love',
#   'educational'],
#  'an': ['angry', 'egg', 'eli', 'armed'],
#  'angry': ['fix'],
#  'fix': ['angelheaded'],
#  'angelheaded': ['hipsters'],
#  'hipsters': ['burning'],
#  'burning': ['for'],
#  'ancient': ['heavenly'],
#  'heavenly': [''],
#  'connection': ['to'],
#  'to': ['the',
#   'heaven',
#   'the',
#   'subways',
#   'holy',
#   'the',
#   '',
#   'bar',
#   'bellevue',
#   'museum',
#   'the',
#   'go',
#   'converse',
#   'africa',
#   '',
#   'giggle',
#   'pierce',
#   'the',
#   'sweeten',
#   'the',
#   'unemploy',
#   'open',
#   'a',
#   'build',
#   'cast',
#   'open',
#   'each',
#   'find',
#   'find',
#   'denver',
#   'denver',
#   'find',
#   'alcatraz',
#   'mexico',
#   'cultivate',
#   'tender',
#   'boys',
#   'the',
#   'narcissus',
#   'woodlawn',
#   'the',
#   'the',
#   'stone',
#   'the',
#   'recreate',
#   'conform',
#   'the',
#   'say',
#   'the',
#   'eat',
#   'heaven',
#   '',
#   'solitude',
#   'the',
#   'its',
#   'a',
#   'drop',
#   'the'],
#  'starry': ['dynamo', ''],
#  'dynamo': ['in', 'moloch'],
#  'in': ['the',
#   'the',
#   'unshaven',
#   'underwear',
#   'wastebaskets',
#   'their',
#   'paint',
#   '',
#   'the',
#   'the',
#   'the',
#   'submarine',
#   'desolate',
#   'total',
#   'newarks',
#   'the',
#   'boxcars',
#   'grand',
#   '',
#   'kansas',
#   'supernatural',
#   'limousines',
#   'fire',
#   'beards',
#   'their',
#   'their',
#   'union',
#   'white',
#   'the',
#   'policecars',
#   'the',
#   'the',
#   'the',
#   'the',
#   'rose',
#   'a',
#   'the',
#   'the',
#   'the',
#   'myriad',
#   'empty',
#   'caves',
#   'familiar',
#   'vast',
#   '',
#   'the',
#   'oblivion',
#   'boxes',
#   'the',
#   '',
#   'the',
#   'their',
#   'despair',
#   'the',
#   'their',
#   'denver',
#   'vain',
#   '',
#   'hopeless',
#   'jail',
#   'their',
#   '',
#   'humorless',
#   'catatonia',
#   'the',
#   'reply',
#   'the',
#   'the',
#   'time',
#   'his',
#   'time',
#   'time',
#   'the',
#   '',
#   'armies',
#   'the',
#   'the',
#   'the',
#   'whom',
#   'whom',
#   'moloch',
#   '',
#   'moloch',
#   'whom',
#   'moloch',
#   'the',
#   'rockland',
#   'rockland',
#   'rockland',
#   'rockland',
#   'rockland',
#   'rockland',
#   'rockland',
#   'rockland',
#   'rockland',
#   'rockland',
#   'rockland',
#   'a',
#   'rockland',
#   'an',
#   'rockland',
#   'the',
#   'rockland',
#   'rockland',
#   'rockland',
#   'rockland',
#   'rockland',
#   'rockland',
#   'my',
#   'tears',
#   'the'],
#  'machin': [''],
#  'ery': ['of'],
#  'night': ['who', 'after', 'with', 'in', 'who', 'with', 'rocking', '', 'and'],
#  'who': ['poverty',
#   'bared',
#   'passed',
#   'were',
#   'cowered',
#   'got',
#   'ate',
#   'chained',
#   'sank',
#   'talked',
#   'vanished',
#   'wandered',
#   'lit',
#   'studied',
#   'loned',
#   'were',
#   'thought',
#   'jumped',
#   'lounged',
#   'disappeared',
#   'reappeared',
#   'burned',
#   'distributed',
#   'broke',
#   'bit',
#   'howled',
#   'let',
#   'blew',
#   'balled',
#   'may',
#   'hiccuped',
#   'lost',
#   'copulated',
#   'sweetened',
#   'went',
#   'faded',
#   'walked',
#   'created',
#   'ate',
#   'wept',
#   'sat',
#   'coughed',
#   'scribbled',
#   'cooked',
#   'plunged',
#   'threw',
#   'cut',
#   'jumped',
#   'sang',
#   'barreled',
#   'drove',
#   'journeyed',
#   'died',
#   '',
#   '',
#   'fell',
#   'crashed',
#   'sang',
#   'retired',
#   'demanded',
#   'threw',
#   'were',
#   'in',
#   'therefore',
#   'dreamt',
#   'entered',
#   'frightened'],
#  'poverty': ['and', 'is'],
#  'and': ['tatters',
#   'holloweyed',
#   'high',
#   '',
#   'blakelight',
#   'listening',
#   'cock',
#   'endless',
#   '',
#   'moon',
#   'tree',
#   'kind',
#   'children',
#   '',
#   'sat',
#   'memories',
#   'anecdotes',
#   'eyeball',
#   'shocks',
#   'jails',
#   'wars',
#   'nights',
#   'tangerian',
#   'migraines',
#   'around',
#   'went',
#   'bop',
#   'lonesome',
#   'followed',
#   'eternity',
#   'so',
#   'the',
#   'ash',
#   'shorts',
#   'undressing',
#   'wailed',
#   'the',
#   'trembling',
#   'shrieked',
#   'intoxication',
#   'were',
#   'manu',
#   'screamed',
#   'were',
#   'caribbean',
#   'the',
#   '',
#   'the',
#   'snip',
#   'insatiate',
#   'fell',
#   'continued',
#   'down',
#   'ended',
#   '',
#   'were',
#   'naked',
#   'adonis',
#   '',
#   'horrors',
#   'opium',
#   'bad',
#   'rose',
#   'rolling',
#   'were',
#   'criedwho',
#   'walked',
#   'forgotten',
#   '',
#   'the',
#   'finally',
#   'light',
#   'breasts',
#   'the',
#   'subsequently',
#   'harlequin',
#   'who',
#   'tears',
#   'fingers',
#   'greystones',
#   'rolling',
#   'the',
#   'the',
#   'the',
#   'the',
#   'even',
#   '',
#   'made',
#   'trapped',
#   'joined',
#   'set',
#   'dash',
#   'measure',
#   'stand',
#   'intel',
#   'shaking',
#   'endless',
#   'angel',
#   'rose',
#   'blew',
#   'aluminum',
#   'ate',
#   'imagi',
#   'unob',
#   'congress',
#   'croak',
#   'antennae',
#   'stone',
#   'banks',
#   'manless',
#   'is',
#   'crucifixions',
#   'suicides',
#   '',
#   'immortal',
#   '',
#   'resurrect',
#   'kiss',
#   'wont'],
#  'tatters': ['and'],
#  'holloweyed': ['and'],
#  'high': ['sat'],
#  'sat': ['', 'through', 'in'],
#  'up': ['smoking',
#   '',
#   'out',
#   'to',
#   'and',
#   'groaning',
#   'their',
#   'in',
#   'electrified'],
#  'smoking': ['in', ''],
#  'supernatural': ['darkness', 'ecstasy'],
#  'darkness': ['of', 'under'],
#  'coldwater': ['flats'],
#  'flats': ['floating'],
#  'floating': ['across'],
#  'across': ['the', 'america'],
#  'tops': ['of'],
#  'cities': ['', 'down', 'moloch'],
#  'contemplating': ['jazz'],
#  'jazz': ['who', 'or', 'finished', 'incarnation', 'in'],
#  'bared': ['their'],
#  'their': ['brains',
#   'money',
#   'pubic',
#   '',
#   'feet',
#   'dark',
#   'arms',
#   '',
#   'knees',
#   'semen',
#   'loveboys',
#   'shoes',
#   'heads',
#   '',
#   'lofts',
#   'watches',
#   'ballot',
#   'heads',
#   'wrists',
#   'innocent',
#   'windows',
#   'ears',
#   'knees',
#   'minds',
#   'hearts',
#   'insanity',
#   '',
#   'own',
#   'skulls',
#   'brains',
#   'backs'],
#  'brains': ['to', 'and'],
#  'heaven': ['under', 'pave', 'which'],
#  'under': ['the', 'junkwith', 'barns', 'the', 'the', 'the', 'meat', 'the', ''],
#  'el': ['and'],
#  'mohammedan': ['angels'],
#  'angels': ['staggering', 'who', 'who', 'crazy'],
#  'staggering': ['on'],
#  'on': ['tene',
#   'the',
#   'benzedrine',
#   'the',
#   'the',
#   'the',
#   'the',
#   'their',
#   'her',
#   'the',
#   'mountaintops',
#   'a',
#   '',
#   'the',
#   'the',
#   'their',
#   'madison',
#   'negroes',
#   'broken',
#   'their',
#   'dadaism',
#   'the',
#   'a',
#   '',
#   'the',
#   'the',
#   'the',
#   'the',
#   'the'],
#  'tene': [''],
#  'ment': ['roofs', 'offices'],
#  'roofs': ['illuminated'],
#  'illuminated': ['who', 'its'],
#  'passed': ['through'],
#  'universities': ['with'],
#  'with': ['radiant',
#   'a',
#   'dreams',
#   'drugs',
#   'waking',
#   'brilliant',
#   'the',
#   'big',
#   'delight',
#   'joy',
#   'a',
#   'a',
#   'a',
#   'a',
#   '',
#   'heartless',
#   'their',
#   'laurel',
#   'their',
#   'flame',
#   'golden',
#   'their',
#   'shaven',
#   'the',
#   'mother',
#   'a',
#   'sensation',
#   'shame',
#   'the',
#   'you',
#   'you',
#   'you',
#   'you',
#   'you',
#   'you',
#   'you',
#   'you',
#   'you',
#   'you',
#   'you',
#   'you',
#   'you',
#   'you',
#   'you',
#   'you',
#   'you',
#   'you',
#   'you'],
#  'radiant': ['cool'],
#  'cool': ['eyes'],
#  'eyes': ['', 'meat', 'sexy', 'are', 'the'],
#  'hallucinating': ['arkansas'],
#  'arkansas': ['and'],
#  'blakelight': ['tragedy'],
#  'tragedy': [''],
#  'among': ['the'],
#  'scholars': ['of'],
#  'war': ['who', 'moloch', 'is'],
#  'were': ['expelled',
#   'visionary',
#   'only',
#   '',
#   'blown',
#   'red',
#   'shifted',
#   '',
#   'forced',
#   'growing',
#   'burned',
#   'run',
#   'left',
#   'given',
#   ''],
#  'expelled': ['from'],
#  'from': ['the', 'battery', 'park', 'its', 'the', 'a'],
#  'academies': ['for'],
#  'crazy': ['', 'in'],
#  'publishing': ['obscene'],
#  'obscene': ['odes'],
#  'odes': ['on'],
#  'windows': ['of', 'in', ''],
#  'skull': ['who', 'no'],
#  'cowered': ['in'],
#  'unshaven': ['rooms'],
#  'rooms': ['in'],
#  'underwear': ['burn', 'were'],
#  'burn': [''],
#  'ing': ['their', 'and', 'plane'],
#  'money': ['in', 'moloch'],
#  'wastebaskets': ['and'],
#  'listening': ['', 'to'],
#  'terror': ['through'],
#  'wall': ['who', 'and', 'with', 'in'],
#  'got': ['busted'],
#  'busted': ['in'],
#  'pubic': ['beards'],
#  'beards': ['returning', 'and'],
#  'returning': ['through', 'years'],
#  'laredo': ['with'],
#  'a': ['belt',
#   '',
#   'hopeless',
#   'sob',
#   'partition',
#   'turkish',
#   'sword',
#   'bottle',
#   'sweetheart',
#   'package',
#   'can',
#   'vision',
#   'million',
#   'sudden',
#   'door',
#   'room',
#   'vision',
#   'vision',
#   'vision',
#   'second',
#   'habit',
#   'hung',
#   'wig',
#   'night',
#   'yellow',
#   'wire',
#   'hopeful',
#   'sudden',
#   'thousand',
#   'canni',
#   'smoking',
#   'thousand',
#   'cloud',
#   'consciousness',
#   'body',
#   'straightjacket',
#   '',
#   'sea'],
#  'belt': ['of'],
#  'marijuana': ['for'],
#  'new': ['york', 'jersey', 'loves'],
#  'york': ['who'],
#  'ate': ['fire', 'the', 'up'],
#  'fire': ['in', 'escapes', ''],
#  'paint': ['hotels'],
#  'hotels': ['or'],
#  'or': ['drank',
#   'purgatoried',
#   'sex',
#   'soup',
#   'with',
#   'digested',
#   'were',
#   'birmingham',
#   'you',
#   'he',
#   'rocky',
#   'tangiers',
#   'southern',
#   '',
#   'grave'],
#  'drank': ['turpentine'],
#  'turpentine': ['in'],
#  'paradise': ['alley'],
#  'alley': ['death', ''],
#  'death': ['or', 'and'],
#  'purgatoried': ['their'],
#  'torsos': ['night'],
#  'after': ['night', '', 'death'],
#  'dreams': ['with', 'woke', '', 'adorations', 'you'],
#  'drugs': ['with'],
#  'waking': ['nightmares'],
#  'nightmares': ['al'],
#  'al': [''],
#  'cohol': ['and'],
#  'cock': ['and'],
#  'endless': ['balls', '', 'head', 'jehovahs', 'oil'],
#  'balls': ['incomparable'],
#  'incomparable': ['blind'],
#  'blind': ['streets', 'windows', 'capitals'],
#  'shuddering': ['cloud', 'mouthwracked'],
#  'cloud': ['and', 'of'],
#  'lightning': ['in'],
#  'mind': ['leaping', 'who', 'for', 'is', 'moloch'],
#  'leaping': ['toward'],
#  'toward': ['poles', 'lonesome'],
#  'poles': ['of'],
#  'canada': [''],
#  'paterson': ['illuminating'],
#  'illuminating': ['all'],
#  'all': ['the',
#   'drained',
#   'night',
#   'night',
#   'night',
#   'over',
#   'the',
#   'together',
#   ''],
#  'mo': [''],
#  'tionless': ['world'],
#  'world': ['of'],
#  'time': ['between', '', '', '', 'unknown', 'come'],
#  'between': ['peyote', ''],
#  'peyote': ['solidities'],
#  'solidities': ['of'],
#  'halls': ['backyard', 'bickering'],
#  'backyard': ['green'],
#  'green': ['tree'],
#  'tree': ['cemetery', ''],
#  'cemetery': [''],
#  'dawns': ['wine'],
#  'wine': ['drunkenness'],
#  'drunkenness': ['over'],
#  'over': ['the', 'with', 'lofty', 'the', 'denver', 'the', 'the'],
#  'rooftops': [''],
#  'storefront': ['boroughs'],
#  'boroughs': ['of'],
#  'teahead': ['joyride'],
#  'joyride': ['neon'],
#  'neon': [''],
#  'blinking': ['traffic'],
#  'traffic': ['light'],
#  'light': ['sun', 'of', 'of', 'of', 'smalltown', 'and', 'streaming'],
#  'sun': ['and', ''],
#  'moon': ['and', 'yacketayakking', '', 'with'],
#  'vibrations': ['in'],
#  'roaring': ['winter', 'over'],
#  'winter': ['dusks', 'midnight'],
#  'dusks': ['of'],
#  'brook': ['', ''],
#  'lyn': ['ashcan', 'bridge'],
#  'ashcan': ['rantings'],
#  'rantings': ['and'],
#  'kind': ['king'],
#  'king': ['light'],
#  'chained': ['themselves'],
#  'subways': ['for'],
#  'ride': ['from'],
#  'battery': ['to'],
#  'holy': ['bronx', 'laughter', 'yells'],
#  'bronx': ['on', 'im'],
#  'benzedrine': [''],
#  'until': ['the', 'the'],
#  'noise': ['of'],
#  'wheels': ['and'],
#  'children': ['brought', 'screaming'],
#  'brought': [''],
#  'them': ['down', 'down', 'with'],
#  'down': ['shuddering',
#   'the',
#   'and',
#   'wall',
#   'crying',
#   'the',
#   'by',
#   'the',
#   'to',
#   'here',
#   'to',
#   'the',
#   'the',
#   'on',
#   'to'],
#  'mouthwracked': ['and'],
#  'battered': ['bleak'],
#  'bleak': ['of', 'furnished'],
#  'brain': ['all'],
#  'drained': ['of'],
#  'brilliance': [''],
#  'drear': ['light'],
#  'zoo': ['who'],
#  'sank': ['all'],
#  'submarine': ['light'],
#  'bickfords': [''],
#  'floated': ['out'],
#  'out': ['and',
#   'of',
#   'incom',
#   'of',
#   'whoring',
#   'in',
#   'of',
#   'of',
#   'of',
#   '',
#   'eternity',
#   'the',
#   'of',
#   'the',
#   'of',
#   'of',
#   'of',
#   'of'],
#  'stale': ['beer'],
#  'beer': ['after', 'a', 'who'],
#  'noon': ['in'],
#  'desolate': ['fugazzis'],
#  'fugazzis': ['listening'],
#  'crack': [''],
#  'doom': ['on', 'of'],
#  'hydrogen': ['jukebox', ''],
#  'jukebox': ['who'],
#  'talked': ['continuously'],
#  'continuously': ['seventy'],
#  'seventy': ['hours'],
#  'hours': ['from', 'to'],
#  'park': ['to'],
#  'pad': ['to'],
#  'bar': ['to'],
#  'bellevue': ['to'],
#  'museum': ['to'],
#  'bridge': ['', 'and', 'this'],
#  'lost': ['battalion', 'their'],
#  'battalion': ['of'],
#  'platonic': ['conversationalists'],
#  'conversationalists': ['jumping'],
#  'jumping': ['', ''],
#  'stoops': ['off'],
#  'off': ['fire', 'windowsills', 'empire', 'the', 'the', 'the', 'the', 'the'],
#  'escapes': ['off'],
#  'windowsills': [''],
#  'empire': ['state'],
#  'state': ['out'],
#  'yacketayakking': ['screaming'],
#  'screaming': ['vomiting', 'under'],
#  'vomiting': ['whispering'],
#  'whispering': ['facts'],
#  'facts': [''],
#  'memories': ['and'],
#  'anecdotes': ['and'],
#  'eyeball': ['kicks'],
#  'kicks': [''],
#  'shocks': ['of', 'will'],
#  'hospitals': ['and'],
#  'jails': ['and'],
#  'wars': ['whole'],
#  'whole': ['intellects', ''],
#  'intellects': ['disgorged'],
#  'disgorged': ['in'],
#  'total': ['recall', 'animal'],
#  'recall': ['for'],
#  'seven': ['days'],
#  'days': [''],
#  'nights': ['with'],
#  'brilliant': ['eyes', 'spaniard'],
#  'meat': ['for', 'trucks'],
#  'synagogue': ['cast'],
#  'cast': ['on', 'their'],
#  'pavement': ['who'],
#  'vanished': ['into'],
#  'into': ['nowhere', 'the', 'the', 'the', '', 'the'],
#  'nowhere': ['zen'],
#  'zen': ['new'],
#  'jersey': ['leaving'],
#  'leaving': ['a', 'no', ''],
#  'trail': ['of'],
#  'ambiguous': ['picture'],
#  'picture': ['postcards'],
#  'postcards': ['of'],
#  'atlantic': ['', 'and'],
#  'city': ['hall', 'to'],
#  'hall': ['suffering', 'and'],
#  'suffering': ['eastern', 'of'],
#  'eastern': ['sweats'],
#  'sweats': ['and'],
#  'tangerian': ['bonegrind'],
#  'bonegrind': [''],
#  'ings': ['and'],
#  'migraines': ['of'],
#  'china': ['under'],
#  'junkwith': [''],
#  'drawal': ['in'],
#  'newarks': ['bleak'],
#  'furnished': ['room'],
#  'room': ['who', 'full', 'emptied'],
#  'wandered': ['around'],
#  'around': ['and', 'at'],
#  'midnight': ['in', 'street', 'solitudebench'],
#  'railroad': ['yard'],
#  'yard': ['wondering'],
#  'wondering': ['where'],
#  'where': ['to',
#   'they',
#   'youre',
#   'you',
#   'you',
#   'youve',
#   'you',
#   'we',
#   'your',
#   'the',
#   'you',
#   'you',
#   'you',
#   'you',
#   'fifty',
#   'you',
#   'you',
#   'there',
#   'we',
#   'we'],
#  'go': ['and'],
#  'went': ['', 'out', 'away'],
#  'no': ['broken', 'crime', 'longer', 'charge'],
#  'broken': ['hearts', 'wineglasses'],
#  'hearts': ['who', 'who'],
#  'lit': ['cigarettes'],
#  'cigarettes': ['in', 'a'],
#  'boxcars': ['boxcars', 'boxcars', 'racketing'],
#  'racketing': [''],
#  'snow': ['toward'],
#  'lonesome': ['farms', 'through', 'for'],
#  'farms': ['in'],
#  'grand': [''],
#  'father': ['night'],
#  'studied': ['plotinus'],
#  'plotinus': ['poe'],
#  'poe': ['st'],
#  'st': ['john'],
#  'john': ['of'],
#  'cross': ['telep', 'in'],
#  'telep': [''],
#  'athy': ['and'],
#  'bop': ['kabbalah'],
#  'kabbalah': ['because'],
#  'because': ['the'],
#  'cosmos': ['in'],
#  'stinctively': ['vibrated'],
#  'vibrated': ['at'],
#  'feet': ['in', 'tail'],
#  'kansas': ['who'],
#  'loned': ['it', 'in'],
#  'it': ['through', 'all', 'should'],
#  'idaho': ['seeking'],
#  'seeking': ['vis', 'jazz'],
#  'vis': [''],
#  'ionary': ['indian'],
#  'indian': ['angels', ''],
#  'visionary': ['indian'],
#  'thought': ['they', 'they', 'in'],
#  'they': ['were', 'thought', 'were', 'broke', 'saw', 'bade', 'jumped'],
#  'only': ['mad', 'one'],
#  'mad': ['when', '', '', 'generation', 'com'],
#  'when': ['baltimore', 'the'],
#  'baltimore': [''],
#  'gleamed': ['in'],
#  'ecstasy': ['who', ''],
#  'jumped': ['in', 'off', 'in', 'off'],
#  'limousines': ['with'],
#  'chinaman': ['of'],
#  'okla': [''],
#  'homa': ['on'],
#  'impulse': ['of'],
#  'street': ['', '', 'iiicarl'],
#  'smalltown': ['rain'],
#  'rain': ['who'],
#  'lounged': ['hungry'],
#  'hungry': ['and'],
#  'houston': [''],
#  'sex': ['or'],
#  'soup': ['and', 'alley', 'of'],
#  'followed': ['the'],
#  'spaniard': ['to'],
#  'converse': ['about'],
#  'about': ['america', ''],
#  'america': ['', 'in'],
#  'eternity': ['a', 'outside', 'who'],
#  'hopeless': ['task', 'cathedrals'],
#  'task': ['and'],
#  'so': ['took'],
#  'took': ['ship'],
#  'ship': [''],
#  'africa': ['who'],
#  'disappeared': ['into'],
#  'volcanoes': ['of'],
#  'mexico': ['leaving', 'to'],
#  'behind': ['nothing', 'a'],
#  'nothing': ['but', 'but', 'but'],
#  'but': ['the', 'their', 'wound', '', 'prepared', 'a'],
#  'shadow': ['of', 'of'],
#  'dungarees': [''],
#  'lava': ['and'],
#  'ash': ['of'],
#  'poetry': ['scattered'],
#  'scattered': ['in'],
#  'place': ['chicago'],
#  'chicago': ['who'],
#  'reappeared': ['on'],
#  'west': ['coast'],
#  'coast': ['investigating'],
#  'investigating': ['the'],
#  'fbi': ['in'],
#  'shorts': ['with'],
#  'big': ['pacifist'],
#  'pacifist': [''],
#  'sexy': ['in'],
#  'dark': ['skin'],
#  'skin': ['passing'],
#  'passing': ['out'],
#  'incom': [''],
#  'prehensible': ['leaflets'],
#  'leaflets': ['who'],
#  'burned': ['cigarette', 'alive'],
#  'cigarette': ['holes'],
#  'holes': ['in'],
#  'arms': ['protesting'],
#  'protesting': [''],
#  'narcotic': ['tobacco'],
#  'tobacco': ['haze'],
#  'haze': ['of'],
#  'capitalism': ['who'],
#  'distributed': ['supercommunist'],
#  'supercommunist': ['pamphlets'],
#  'pamphlets': ['in'],
#  'union': [''],
#  'square': ['weeping'],
#  'weeping': ['and', 'in'],
#  'undressing': ['while'],
#  'while': ['the', 'you'],
#  'sirens': [''],
#  'los': ['alamos'],
#  'alamos': ['wailed'],
#  'wailed': ['them', '', 'who'],
#  'staten': ['island'],
#  'island': ['ferry', ''],
#  'ferry': ['also'],
#  'also': [''],
#  'broke': ['down', 'their'],
#  'crying': ['in'],
#  'white': ['gymnasiums'],
#  'gymnasiums': ['naked'],
#  'naked': ['', 'angel', '', 'and', 'mind'],
#  'trembling': ['before', ''],
#  'before': ['the', 'you'],
#  'machinery': ['of', 'moloch'],
#  'other': [''],
#  'skeletons': ['who'],
#  'bit': ['detectives', 'of'],
#  'detectives': ['in'],
#  'neck': ['and'],
#  'shrieked': ['with'],
#  'delight': [''],
#  'policecars': ['for'],
#  'committing': ['no'],
#  'crime': ['but'],
#  'own': ['wild', 'bodies', 'souls'],
#  'wild': ['cooking', 'eyes'],
#  'cooking': ['pederasty'],
#  'pederasty': ['and'],
#  'intoxication': ['who'],
#  'howled': ['on'],
#  'knees': ['in', 'in'],
#  'subway': ['and', 'window'],
#  'dragged': ['off'],
#  'roof': ['waving', 'to', 'to', 'theyve'],
#  'waving': ['genitals', ''],
#  'genitals': ['and'],
#  'manu': [''],
#  'scripts': ['who'],
#  'let': ['themselves', 'us'],
#  'be': ['fucked', 'crowned', 'left'],
#  'fucked': ['in'],
#  'ass': ['by', 'and'],
#  'saintly': [''],
#  'motorcyclists': ['and'],
#  'screamed': ['with'],
#  'joy': ['who'],
#  'blew': ['and', 'the'],
#  'blown': ['by'],
#  'those': ['human'],
#  'human': ['seraphim', '', 'jesus'],
#  'seraphim': [''],
#  'sailors': ['caresses'],
#  'caresses': ['of'],
#  'caribbean': [''],
#  'love': ['who', 'dream', 'into', 'is'],
#  'balled': ['in'],
#  'morning': ['in', '', 'were'],
#  'evenings': ['in'],
#  'rose': ['', 'up', 'twisted', 'reincarnate'],
#  'gardens': ['and'],
#  'grass': ['of'],
#  'public': ['parks'],
#  'parks': ['and', 'moloch'],
#  'cemeteries': ['scattering'],
#  'scattering': ['their'],
#  'semen': ['freely'],
#  'freely': ['to'],
#  'whomever': ['come'],
#  'come': ['who', 'eluding', 'after', 'to'],
#  'may': ['who'],
#  'hiccuped': ['endlessly'],
#  'endlessly': ['trying'],
#  'trying': ['to'],
#  'giggle': ['but'],
#  'wound': ['up'],
#  'sob': ['behind'],
#  'partition': ['in'],
#  'turkish': ['bath'],
#  'bath': [''],
#  'blond': [''],
#  'angel': ['came', 'beat'],
#  'came': ['to', 'back'],
#  'pierce': [''],
#  'sword': ['who'],
#  'loveboys': ['to'],
#  'three': ['old', 'times'],
#  'old': ['shrews', 'and', 'men'],
#  'shrews': ['of'],
#  'fate': ['', 'is'],
#  'one': ['eyed', 'eyed', 'eyed', 'free', 'symbolic'],
#  'eyed': ['shrew', 'shrew', 'shrew', 'in'],
#  'shrew': ['of', 'that', 'that'],
#  'heterosexual': ['dollar'],
#  'dollar': [''],
#  'that': ['winks', 'does', '', 'shivered', 'youre', 'coughs'],
#  'winks': ['out'],
#  'womb': [''],
#  'does': ['nothing'],
#  'sit': ['on', 'lonely'],
#  'her': ['ass', 'heroes'],
#  'snip': ['the'],
#  'intellectual': ['golden'],
#  'golden': ['', 'heads'],
#  'threads': ['of'],
#  'craftsmans': ['loom'],
#  'loom': ['who'],
#  'copulated': ['ecstatic'],
#  'ecstatic': ['and'],
#  'insatiate': ['with'],
#  'bottle': ['of'],
#  'sweetheart': ['a'],
#  'package': ['of'],
#  'can': [''],
#  'dle': ['and'],
#  'fell': ['off', 'on', 'out', 'on'],
#  'bed': ['and'],
#  'continued': ['along'],
#  'along': [''],
#  'floor': ['and', 'of'],
#  'ended': ['fainting'],
#  'fainting': [''],
#  'vision': ['of', 'or', 'or', 'to'],
#  'ultimate': ['cunt'],
#  'cunt': ['and'],
#  'eluding': ['the'],
#  'last': ['gyzym', 'fantastic', '', 'telephone', 'fur', 'piece', 'radio'],
#  'gyzym': ['of'],
#  'consciousness': ['who', 'together', 'without'],
#  'sweetened': ['the'],
#  'snatches': ['of'],
#  'million': ['girls'],
#  'girls': ['trembling', ''],
#  'sunset': ['and'],
#  'red': ['eyed'],
#  'prepared': ['to'],
#  'sweeten': ['the'],
#  'snatch': ['of'],
#  'rise': ['flashing'],
#  'flashing': ['buttocks'],
#  'buttocks': ['under'],
#  'barns': ['and'],
#  'lake': ['who'],
#  'whoring': ['through'],
#  'colorado': ['in'],
#  'myriad': [''],
#  'stolen': ['nightcars'],
#  'nightcars': ['nc'],
#  'nc': ['secret'],
#  'secret': ['hero', 'gasstation'],
#  'hero': ['of'],
#  'these': [''],
#  'poems': ['cocksman'],
#  'cocksman': ['and'],
#  'adonis': ['of'],
#  'denverjoy': [''],
#  'memory': ['of'],
#  'his': ['innumerable', 'naked'],
#  'innumerable': ['lays'],
#  'lays': ['of'],
#  'empty': ['lots'],
#  'lots': [''],
#  'diner': ['backyards'],
#  'backyards': ['moviehouses'],
#  'moviehouses': [''],
#  'rickety': ['rows'],
#  'rows': ['on'],
#  'mountaintops': ['in'],
#  'caves': ['or'],
#  'gaunt': ['waitresses'],
#  'waitresses': ['in'],
#  'familiar': ['roadside'],
#  'roadside': ['lonely'],
#  'lonely': ['pet', 'moloch'],
#  'pet': [''],
#  'ticoat': ['upliftings'],
#  'upliftings': [''],
#  'especially': ['secret'],
#  'gasstation': [''],
#  'solipsisms': ['of'],
#  'johns': [''],
#  'hometown': ['alleys'],
#  'alleys': ['too'],
#  'too': ['who'],
#  'faded': ['out'],
#  'vast': ['sordid', 'stone'],
#  'sordid': ['movies'],
#  'movies': ['were'],
#  'shifted': ['in'],
#  'woke': ['on'],
#  'sudden': ['manhattan', 'flash'],
#  'manhattan': ['and'],
#  'picked': ['themselves'],
#  'basements': ['hung'],
#  'hung': ['', 'jury'],
#  'heartless': ['tokay'],
#  'tokay': ['and'],
#  'horrors': ['of'],
#  'third': [''],
#  'avenue': ['iron', 'amid'],
#  'iron': ['dreams', 'regiments'],
#  'stumbled': ['to'],
#  'unemploy': [''],
#  'offices': ['who'],
#  'walked': ['all', 'away'],
#  'shoes': ['full'],
#  'full': ['of', 'of', 'of'],
#  'blood': ['on', 'and', 'is'],
#  'snowbank': ['docks'],
#  'docks': ['waiting'],
#  'waiting': ['for', 'for'],
#  'door': ['in', 'closed', 'of'],
#  'east': ['river', 'pilgrim'],
#  'river': ['to', 'dreams', 'flips', 'they', 'into'],
#  'open': ['to', 'antique', ''],
#  'steamheat': [''],
#  'opium': ['who'],
#  'created': ['great'],
#  'great': ['suicidal', 'writers'],
#  'suicidal': ['dramas'],
#  'dramas': ['on'],
#  'apartment': [''],
#  'cliffbanks': ['of'],
#  'hudson': ['under'],
#  'wartime': [''],
#  'blue': ['floodlight'],
#  'floodlight': ['of'],
#  'heads': ['shall', 'every', 'and', ''],
#  'shall': [''],
#  'crowned': ['with', ''],
#  'laurel': ['in'],
#  'oblivion': ['who'],
#  'lamb': ['stew'],
#  'stew': ['of'],
#  'imagination': ['or'],
#  'digested': [''],
#  'crab': ['at'],
#  'muddy': ['bottom'],
#  'bottom': ['of'],
#  'rivers': ['of'],
#  'bowery': ['who'],
#  'wept': ['at'],
#  'romance': ['of'],
#  'pushcarts': ['full'],
#  'onions': ['and'],
#  'bad': ['music'],
#  'music': ['who'],
#  'boxes': ['breathing'],
#  'breathing': ['in'],
#  'build': ['harpsichords'],
#  'harpsichords': ['in'],
#  'lofts': ['who'],
#  'coughed': ['on'],
#  'sixth': ['floor'],
#  'harlem': ['crowned'],
#  'flame': ['under'],
#  'tubercular': ['sky'],
#  'sky': ['surrounded', 'moloch'],
#  'surrounded': [''],
#  'orange': ['crates'],
#  'crates': ['of'],
#  'theology': ['who'],
#  'scribbled': ['all'],
#  'rocking': ['and'],
#  'rolling': ['over', 'in'],
#  'lofty': [''],
#  'incantations': ['which'],
#  'which': ['in', 'exists'],
#  'yellow': ['morning', 'paper'],
#  'stanzas': ['of', 'of'],
#  'gibberish': ['who'],
#  'cooked': ['rotten'],
#  'rotten': ['animals'],
#  'animals': ['lung'],
#  'lung': ['heart'],
#  'heart': ['feet', 'of'],
#  'tail': ['borsht'],
#  'borsht': [''],
#  'tortillas': ['dreaming'],
#  'dreaming': ['of'],
#  'pure': ['vegetable', 'machinery'],
#  'vegetable': [''],
#  'kingdom': ['who'],
#  'plunged': ['themselves'],
#  'trucks': ['looking'],
#  'egg': ['who'],
#  'threw': ['their', 'up', 'potato'],
#  'watches': ['off'],
#  'ballot': [''],
#  'outside': ['of', 'o'],
#  'alarm': ['clocks'],
#  'clocks': [''],
#  'every': ['day'],
#  'day': ['for'],
#  'next': ['decade'],
#  'decade': ['who'],
#  'cut': ['their'],
#  'wrists': ['three'],
#  'times': ['successively'],
#  'successively': ['unsuccess'],
#  'unsuccess': [''],
#  'fully': ['gave'],
#  'gave': ['up'],
#  'forced': ['to'],
#  'antique': [''],
#  'stores': ['where'],
#  'growing': [''],
#  'criedwho': ['were'],
#  'alive': ['in'],
#  'innocent': ['flannel', 'and'],
#  'flannel': ['suits'],
#  'suits': [''],
#  'madison': ['avenue'],
#  'amid': ['blasts'],
#  'blasts': ['of'],
#  'leaden': ['verse'],
#  'verse': [''],
#  'tankedup': ['clatter'],
#  'clatter': ['of'],
#  'regiments': [''],
#  'fashion': [''],
#  'nitroglycerine': ['shrieks'],
#  'shrieks': ['of'],
#  'fairies': ['of'],
#  'advertising': [''],
#  'mustard': ['gas'],
#  'gas': ['of'],
#  'sinis': [''],
#  'ter': ['intelligent'],
#  'intelligent': ['editors'],
#  'editors': ['or'],
#  'run': ['down', 'outside'],
#  'drunken': ['taxicabs'],
#  'taxicabs': ['of'],
#  'absolute': ['reality', 'heart'],
#  'reality': ['who', 'in'],
#  'brooklyn': ['bridge'],
#  'this': ['actually', 'invisible'],
#  'actually': ['hap'],
#  'hap': [''],
#  'pened': ['and'],
#  'away': ['unknown', 'to'],
#  'unknown': ['and', ''],
#  'forgotten': [''],
#  'ghostly': ['daze', 'clothes'],
#  'daze': ['of'],
#  'chinatown': ['soup'],
#  'ways': [''],
#  'firetrucks': ['not'],
#  'not': ['even', 'safe', 'safe'],
#  'even': ['one', 'that'],
#  'free': ['beer', 'im'],
#  'sang': ['out', 'sweet'],
#  'despair': ['fell'],
#  'window': ['jumped', 'and'],
#  'filthy': ['pas'],
#  'pas': [''],
#  'saic': ['leaped'],
#  'leaped': ['on'],
#  'negroes': ['cried'],
#  'cried': ['all'],
#  'danced': ['on'],
#  'wineglasses': ['barefoot'],
#  'barefoot': ['smashed'],
#  'smashed': [''],
#  'phonograph': ['records'],
#  'records': ['of'],
#  'nostalgic': ['european'],
#  'european': [''],
#  'german': ['jazz'],
#  'finished': ['the'],
#  'whiskey': ['and'],
#  'groaning': ['into'],
#  'bloody': ['toilet'],
#  'toilet': ['moans'],
#  'moans': [''],
#  'ears': ['and'],
#  'blast': ['of'],
#  'colossal': ['steam'],
#  'steam': [''],
#  'whistles': ['who'],
#  'barreled': ['down'],
#  'highways': ['of'],
#  'past': ['journeying'],
#  'journeying': [''],
#  'each': ['others', 'others'],
#  'others': ['hotrodgolgotha', 'salvation'],
#  'hotrodgolgotha': ['jailsolitude'],
#  'jailsolitude': [''],
#  'watch': ['or'],
#  'birmingham': ['jazz'],
#  'incarnation': ['who'],
#  'drove': ['crosscountry'],
#  'crosscountry': ['seventytwo'],
#  'seventytwo': ['hours'],
#  'find': ['out', 'out', 'out'],
#  'if': ['i'],
#  'had': ['a', 'a', ''],
#  'you': ['had',
#   'are',
#   'speechless',
#   'in',
#   'in',
#   'must',
#   'in',
#   'imitate',
#   'in',
#   'in',
#   'laugh',
#   'in',
#   'in',
#   'in',
#   'in',
#   'drink',
#   'in',
#   'pun',
#   'in',
#   'scream',
#   'in',
#   'bang',
#   'in',
#   'in',
#   'accuse',
#   'in',
#   'will',
#   'in',
#   'in',
#   'in',
#   'in',
#   'walk'],
#  'he': ['had'],
#  'journeyed': ['to'],
#  'denver': ['who', 'who', '', '', 'and', 'is'],
#  'died': ['in'],
#  'back': ['to'],
#  'waited': ['in'],
#  'vain': ['who'],
#  'watched': ['over'],
#  'brooded': [''],
#  'finally': ['went', ''],
#  'now': ['denver', 'youre'],
#  'is': ['lonesome',
#   'pure',
#   'running',
#   'a',
#   'a',
#   'endless',
#   'electricity',
#   'the',
#   'a',
#   'the',
#   'everywhere',
#   'reported',
#   'innocent',
#   ''],
#  'heroes': ['who'],
#  'cathedrals': ['praying'],
#  'praying': [''],
#  'salvation': ['and'],
#  'breasts': ['', 'of'],
#  'soul': ['illuminated', 'rock', 'between', 'to', 'is', 'early', '', 'to'],
#  'its': ['hair', 'body', 'pilgrimage'],
#  'hair': ['for'],
#  'second': ['who'],
#  'crashed': ['through'],
#  'jail': ['waiting'],
#  'impossible': ['criminals'],
#  'criminals': ['with'],
#  'charm': ['of'],
#  'sweet': [''],
#  'blues': ['to'],
#  'alcatraz': ['who'],
#  'retired': ['to'],
#  'cultivate': ['a'],
#  'habit': ['or'],
#  'rocky': [''],
#  'mount': ['to'],
#  'tender': ['buddha'],
#  'buddha': ['or'],
#  'tangiers': ['to'],
#  'boys': ['', 'sobbing'],
#  'southern': ['pacific'],
#  'pacific': ['to'],
#  'black': ['locomotive'],
#  'locomotive': ['or'],
#  'harvard': ['to'],
#  'narcissus': ['to'],
#  'woodlawn': ['to'],
#  'daisychain': ['or'],
#  'grave': ['who'],
#  'demanded': ['sanity'],
#  'sanity': ['trials'],
#  'trials': ['accusing'],
#  'accusing': ['the'],
#  'radio': ['of', 'with', 'im'],
#  'hyp': [''],
#  'notism': [''],
#  'left': ['with', 'to'],
#  'insanity': ['', 'and'],
#  'hands': [''],
#  'jury': ['who'],
#  'potato': ['salad'],
#  'salad': ['at'],
#  'ccny': ['lecturers'],
#  'lecturers': ['on'],
#  'dadaism': [''],
#  'subsequently': ['presented'],
#  'presented': ['themselves'],
#  'granite': ['steps', 'cocks'],
#  'steps': ['of'],
#  'madhouse': ['with', 'im'],
#  'shaven': ['heads'],
#  'harlequin': ['speech'],
#  'speech': ['of'],
#  'suicide': ['demanding'],
#  'demanding': ['in'],
#  'stantaneous': ['lobotomy'],
#  'lobotomy': ['and'],
#  'given': ['instead'],
#  'instead': ['the'],
#  'concrete': ['void'],
#  'void': ['of', 'im'],
#  'insulin': [''],
#  'metrazol': ['electricity'],
#  'electricity': ['hydrotherapy', 'and'],
#  'hydrotherapy': ['psycho'],
#  'psycho': [''],
#  'therapy': ['occupational', 'pingpong'],
#  'occupational': ['therapy'],
#  'pingpong': ['', 'table', 'of'],
#  'amnesia': ['who'],
#  'humorless': ['protest'],
#  'protest': ['overturned'],
#  'overturned': ['only'],
#  'symbolic': [''],
#  'table': ['resting'],
#  'resting': ['briefly'],
#  'briefly': ['in'],
#  'catatonia': ['returning'],
#  'years': ['later', 'ii', 'animal'],
#  'later': ['truly'],
#  'truly': ['bald'],
#  'bald': ['except'],
#  'except': ['for'],
#  'wig': ['of'],
#  'tears': ['and', ''],
#  'fingers': ['to', ''],
#  'visible': ['mad'],
#  'man': ['doom'],
#  'wards': ['of'],
#  'madtowns': ['of'],
#  'pilgrim': ['states'],
#  'states': ['rocklands', 'under', 'that'],
#  'rocklands': ['and'],
#  'greystones': ['foetid'],
#  'foetid': [''],
#  'bickering': ['with'],
#  'echoes': ['of'],
#  'rock': [''],
#  'solitudebench': [''],
#  'dolmenrealms': ['of'],
#  'dream': ['of', 'and', ''],
#  'life': ['a', 'butchered'],
#  'mare': ['bodies'],
#  'bodies': ['turned', 'good', 'of'],
#  'turned': ['to'],
#  'stone': ['as', 'of', 'moloch'],
#  'as': ['heavy', 'the'],
#  'heavy': ['as', ''],
#  'mother': ['finally', 'im'],
#  'fantastic': ['book'],
#  'book': [''],
#  'flung': ['out'],
#  'tenement': ['window'],
#  'closed': ['at'],
#  'am': ['and', 'not', 'a', 'im'],
#  'telephone': [''],
#  'slammed': ['at'],
#  'reply': ['and'],
#  'fur': [''],
#  'nished': ['room'],
#  'emptied': ['down'],
#  'piece': ['of'],
#  'mental': ['furniture', 'moloch'],
#  'furniture': ['a'],
#  'paper': ['rose'],
#  'twisted': [''],
#  'wire': ['hanger'],
#  'hanger': ['in'],
#  'closet': ['and'],
#  'imaginary': ['nothing', 'walls'],
#  'hopeful': ['little'],
#  'little': ['bit'],
#  'hallucinationah': ['carl'],
#  'carl': ['while', 'solomon'],
#  'are': ['not', 'judgment', 'ten', 'a', 'great', 'twentyfivethousand'],
#  'safe': ['i', 'and'],
#  'youre': ['really', 'madder', ''],
#  'really': ['in'],
#  'animal': ['soup', 'screams'],
#  'timeand': ['who'],
#  'therefore': ['ran'],
#  'ran': ['through'],
#  'icy': ['streets'],
#  'obsessed': [''],
#  'flash': ['of'],
#  'alchemy': ['of'],
#  'use': [''],
#  'ellipse': ['the'],
#  'catalog': ['the'],
#  'meter': [''],
#  'vibrat': [''],
#  'plane': ['who'],
#  'dreamt': ['and'],
#  'made': ['incarnate'],
#  'incarnate': ['gaps'],
#  'gaps': ['in'],
#  'space': [''],
#  'images': ['juxtaposed', ''],
#  'juxtaposed': ['and'],
#  ...}

# %% [markdown]
# ## Create a Text Generator

# %%
import random

def generate_sentence(chain, count=15):
    '''Input a dictionary in the format of key = current word, value = list of next words
       along with the number of words you would like to see in your generated sentence.'''

    word1 = random.choice(list(chain.keys()))
    sentence = word1.capitalize()

    for i in range(count-1):
        word2 = random.choice(chain[word1])
        word1 = word2
        sentence += ' ' + word2

    sentence += '.'
    return(sentence)

# %%
generate_sentence(allen_dict)
# Out:
# 'Whomever come who    the crab at dawn  with you in boxes.'

# %% [markdown]
# ## Additional Exercises

# %% [markdown]
# 1. Try making the generate_sentence function better. Maybe allow it to end with a random punctuation mark or end whenever it gets to a word that already ends with a punctuation mark.

# %%
import random

def generate_sentence(chain, count=5):
    '''Input a dictionary in the format of key = current word, value = list of next words
       along with the number of words you would like to see in your generated sentence.'''

    word1 = random.choice(list(chain.keys()))
    sentence = word1.capitalize()

    for i in range(count-1):
        word2 = random.choice(chain[word1])
        word1 = word2
        sentence += ' ' + word2
    
    if not(sentence.endswith('.')):
        punctuation_list=['.','?','!',':','-',';']
        punctuation=random.choice(punctuation_list)
        sentence += punctuation
    return(sentence)

generate_sentence(allen_dict)
# Out:
# 'Blood is the use :'
